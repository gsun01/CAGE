# %%
import sys
print(sys.executable)
sys.path.append('../')

# this prevents the need to restart the kernel every time a local module is changed
# %load_ext autoreload
# %autoreload 2
# Out:
# /grad/sguotong/.conda/envs/.cavGZ_venv/bin/python

# %%
from include.bessel import initialize_bessel_table, BesselJZeros, BesselJpZeros
initialize_bessel_table(10, 10)

# print out a table of BesselJZeros
print("BesselJZeros (m,n): \n")
print("k |  J_0(x) |  J_1(x) |  J_2(x) |  J_3(x) |  J_4(x) |  J_5(x) |\n")
for n in range(1, 6):
    str_out = f"{n} |"
    for m in range(0, 6):
        str_out += f" {BesselJZeros(m, n):.5f} |"

    print(str_out)

print("\n https://mathworld.wolfram.com/BesselFunctionZeros.html")
# Out:
# BesselJZeros (m,n):
#
# k |  J_0(x) |  J_1(x) |  J_2(x) |  J_3(x) |  J_4(x) |  J_5(x) |
#
# 1 | 2.40483 | 3.83171 | 5.13562 | 6.38016 | 7.58834 | 8.77148 |
# 2 | 5.52008 | 7.01559 | 8.41724 | 9.76102 | 11.06471 | 12.33860 |
# 3 | 8.65373 | 10.17347 | 11.61984 | 13.01520 | 14.37254 | 15.70017 |
# 4 | 11.79153 | 13.32369 | 14.79595 | 16.22347 | 17.61597 | 18.98013 |
# 5 | 14.93092 | 16.47063 | 17.95982 | 19.40942 | 20.82693 | 22.21780 |
#
#  https://mathworld.wolfram.com/BesselFunctionZeros.html

# %%
from include.cavity_modes import CavityModeHelper
import numpy as np
import matplotlib.pyplot as plt

a = 0.1  # radius in meters
L = 0.5  # length in meters
family = "TE"
m, n, p = 2, 1, 2
sign = "-"
cavHelper = CavityModeHelper(a, L)
w_TE212 = cavHelper.omega_mnp(family, m, n, p)
f_TE212 = w_TE212/(2*np.pi)*0.3  # in GHz
Er, Ephi, Ez = cavHelper.mode_fn_callables(family, m, n, p, sign)

# plot a slice near z=0
# THIS SHOULD BE MOVED TO A HELPER FILE IN THE FUTURE
def plot_disk_slice(Fr, Fphi, Fz, a, z0, *, r_pts=200, ph_pts=200, title="", func_name="", show_components=False):
    x = np.linspace(-a, a, 2*r_pts)
    y = np.linspace(-a, a, 2*r_pts)
    X, Y = np.meshgrid(x, y, indexing="xy")
    R = np.hypot(X, Y)
    Phi = np.arctan2(Y, X)
    Z = np.full_like(R, z0)
    disk = R <= a
    eps = 1e-6

    Frv = Fr(R, Phi, Z)
    Fphiv = Fphi(R, Phi, Z)
    Fzv = Fz(R, Phi, Z)

    Fr_real, Fr_imag, Fr_mag = np.real(Frv), np.imag(Frv), np.abs(Frv)
    Fphi_real, Fphi_imag, Fphi_mag = np.real(Fphiv), np.imag(Fphiv), np.abs(Fphiv)
    Fz_real, Fz_imag, Fz_mag = np.real(Fzv), np.imag(Fzv), np.abs(Fzv)
    norm = np.sqrt(Fr_mag**2 + Fphi_mag**2 + Fz_mag**2)

    # one plot of the norm
    fig2, ax2 = plt.subplots(figsize=(6, 5))
    norm = np.where(disk, norm, np.nan)
    plt_norm = ax2.pcolormesh(X, Y, norm, shading="auto", cmap="viridis", zorder=1)
    # vector plot on top of norm plot
    Fx = Fr_imag * np.cos(Phi) - Fphi_imag * np.sin(Phi)
    Fy = Fr_imag * np.sin(Phi) + Fphi_imag * np.cos(Phi)
    Fxy_mag = np.sqrt(Fx**2 + Fy**2) + eps
    Fx /= Fxy_mag
    Fy /= Fxy_mag

    # mask outside the disk and avoid singular arrows near |F|≈0
    U = np.where(disk, Fx, np.nan)
    V = np.where(disk, Fy, np.nan)
    M = np.where(disk, Fxy_mag, np.nan)
    # normalize stream directions
    L = np.sqrt(U**2 + V**2)
    U = U / (L + eps)
    V = V / (L + eps)
    U[L < eps] = np.nan; V[L < eps] = np.nan
    sp = ax2.streamplot(
        X, Y, U, V,
        density=1.2,
        color="k",
        linewidth=0.5,
        arrowsize=0.7,
        minlength=0.05, maxlength=0.1,
        integration_direction="both",
        broken_streamlines=False,
        zorder=2,
    )

    ax2.add_patch(plt.Circle((0, 0), a, edgecolor="0.3", facecolor="none", linewidth=3, zorder=3))
    ax2.set_aspect("equal", "box")
    ax2.set_xlim(-1.1*a, 1.1*a); ax2.set_ylim(-1.1*a, 1.1*a)
    ax2.set_title(f"|{func_name}|")
    fig2.colorbar(plt_norm, ax=ax2)
    plt.suptitle(title or f"Disk slice at z={z0:.3g}")
    plt.show()

    if not show_components: return
    
    # plot 3*3 subplots of magnitude
    fig, axs = plt.subplots(3, 3, figsize=(15, 12))
    comp_dict = {
        "r": (Fr_real, Fr_imag, Fr_mag),
        "phi": (Fphi_real, Fphi_imag, Fphi_mag),
        "z": (Fz_real, Fz_imag, Fz_mag)
    }
    for i, key in enumerate(["r", "phi", "z"]):
        real, imag, mag = comp_dict[key]
        real = np.where(disk, real, np.nan)
        imag = np.where(disk, imag, np.nan)
        mag = np.where(disk, mag, np.nan)

        ax_real, ax_imag, ax_mag = axs[i, 0], axs[i, 1], axs[i, 2]
        plt_real = ax_real.pcolormesh(X, Y, real, shading="auto", cmap="viridis")
        ax_real.add_patch(plt.Circle((0, 0), a, edgecolor="0.3", facecolor="none", linewidth=3, zorder=3))
        ax_real.set_aspect("equal", "box")
        ax_real.set_xlim(-1.1*a, 1.1*a); ax_real.set_ylim(-1.1*a, 1.1*a)
        ax_real.set_title(f"Re({func_name}_{key})")

        plt_imag = ax_imag.pcolormesh(X, Y, imag, shading="auto", cmap="viridis")
        ax_imag.add_patch(plt.Circle((0, 0), a, edgecolor="0.3", facecolor="none", linewidth=3, zorder=3))
        ax_imag.set_aspect("equal", "box")
        ax_imag.set_xlim(-1.1*a, 1.1*a); ax_imag.set_ylim(-1.1*a, 1.1*a)
        ax_imag.set_title(f"Im({func_name}_{key})")

        plt_mag = ax_mag.pcolormesh(X, Y, mag, shading="auto", cmap="viridis")
        ax_mag.add_patch(plt.Circle((0, 0), a, edgecolor="0.3", facecolor="none", linewidth=3, zorder=3))
        ax_mag.set_aspect("equal", "box")
        ax_mag.set_xlim(-1.1*a, 1.1*a); ax_mag.set_ylim(-1.1*a, 1.1*a)
        ax_mag.set_title(f"|{func_name}_{key}|")

    fig.colorbar(plt_mag, ax=axs.ravel().tolist())
    plt.suptitle(title or f"Disk slice at z={z0:.3g}")
    plt.show()

z0_over_L = 0.01
z0 = z0_over_L * L
title = f"{family}{m}{n}{p}, f={f_TE212:.3g} GHz, z={z0_over_L:.3g}L"
plot_disk_slice(Er, Ephi, Ez, a, z0, title=title, func_name="E")

family = "TM"
m, n, p = 0, 1, 0
sign = "-"
w_TM010 = cavHelper.omega_mnp(family, m, n, p)
f_TM010 = w_TM010/(2*np.pi)*0.3  # in GHz
Er, Ephi, Ez = cavHelper.mode_fn_callables(family, m, n, p, sign)
title = f"{family}{m}{n}{p}, f={f_TM010:.3g} GHz, z={z0_over_L:.3g}L"
plot_disk_slice(Er, Ephi, Ez, a, z0, title=title, func_name="E")

# %%
from include.j_eff import j_eff_callables

pol = "+"
Jr, Jphi, Jz = j_eff_callables(pol, w_TM010, 0, 0, 0)
plot_disk_slice(Jr, Jphi, Jz, a, z0, title=title, func_name="j_eff")

# %%
Nr, Nphi, Nz = 200, 256, 96
r = np.linspace(0.0, a, Nr, endpoint=True)
phi = np.linspace(0.0, 2*np.pi, Nphi, endpoint=False)
z = np.linspace(-L/2, +L/2, Nz, endpoint=True)

R, PHI, Z = np.meshgrid(r, phi, z, indexing="ij")   # shape: [Nr, Nphi, Nz]

family = "TE"
m, n, p = 2, 1, 1
sign = "-"

Er, Ephi, Ez = cavHelper.mode_fn_vectorized(R, PHI, Z, family, m, n, p, sign)
w_mnp = cavHelper.omega_mnp(family, m, n, p)
f_mnp = w_mnp/(2*np.pi)*0.3  # in GHz
print(f"{family}{m}{n}{p}, f={f_mnp:.3g} GHz")
# Out:
# TE211, f=1.49 GHz

# %%
from include.antenna_pattern import antenna_pattern
from include.custom_types import asarr_np.float64
import numpy as np

Nb, Na, Npsi = 60, 1, 1
beta = np.linspace(0.0, np.pi, Nb, endpoint=True)
alpha = asarr_np.float64(0.0)  # single value for alpha for linear polarization
psi = asarr_np.float64(0)  # single value for psi for linear polarization

pol = "+"

eta = antenna_pattern(r, phi, z, Er, Ephi, Ez, pol=pol, 
                      wg=w_mnp, a=a, L=L, beta=beta, alpha=alpha, psi=psi,
                      savefile="eta_TE211_+.npy")

import numpy as np
import matplotlib.pyplot as plt

PATH = "eta_TE211_+.npy"

eta = np.load(PATH)                        # shape (Nb, Na, Npsi)
curve = eta[:, 0, 0].astype(float)         # take α=0, ψ=0 slice
Nb = curve.size
beta = np.linspace(0.0, np.pi, Nb, endpoint=True)

# Mirror to cover 0..2π without duplicating endpoints
theta_full = np.r_[beta, beta + np.pi]
r_full     = np.r_[curve, curve]

fig = plt.figure(figsize=(6,6), dpi=150)
ax = plt.subplot(111, projection="polar")
ax.plot(theta_full, r_full, linewidth=0.5)   # no color specified
ax.set_theta_zero_location("E")              # 0° at the right
ax.set_theta_direction(1)                   # clockwise (matches your example)
ax.set_rlabel_position(90)                   # radial labels at 90°
ax.grid(True, linewidth=0.8, alpha=0.7)
ax.set_title(PATH.replace(".npy",""), va="bottom")
plt.tight_layout()
plt.show()
# Out:
# Is E field finite? True
# Norm is 0.002945558357496856
# Calculating j_eff and int(E dot J) in batches...
#   Starting beta batch 0 to 4...
# Loaded kernel functions.
# n_vec shape: (4,), (4,), (4,)
# q_field shape: (200, 256, 96, 4)
# e6 shape: (6, 4)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       8 psi = asarr_np.float64(0)  # single value for psi for linear polarization
#      10 pol = "+"
# ---> 12 eta = antenna_pattern(r, phi, z, Er, Ephi, Ez, pol=pol,
#      13                       wg=w_mnp, a=a, L=L, beta=beta, alpha=alpha, psi=psi,
#      14                       savefile="eta_TE211_+.npy")
#      16 import numpy as np
#      17 import matplotlib.pyplot as plt
#
# File /nfshome/sguotong/projects/CaGe/notebooks/../include/antenna_pattern.py:68, in antenna_pattern(r, phi, z, Er3, Ephi3, Ez3, pol, wg, a, L, beta, alpha, psi, savefile)
#      66 print(f"  Starting beta batch {s} to {min(s+batch, Nbeta)}...", flush=True)
#      67 BB = beta[s:s+batch]  # (B,)
# ---> 68 jr4, jphi4, jz4 = j_eff_on_grid(BB, alpha, psi, pol, R3, PHI3, Z3, wg)
#      70 E_dot_j = (np.conj(Er4)*jr4 + np.conj(Ephi4)*jphi4 + np.conj(Ez4)*jz4)
#      71 integrand = E_dot_j * R4  # include Jacobian r
#
# File /nfshome/sguotong/projects/CaGe/notebooks/../include/j_eff_from_ana.py:167, in j_eff_on_grid(BETA, alpha, psi, pol, R3, PHI3, Z3, wg, path)
#     164 e6 = pol_tensor(alpha, BETA, psi, pol)
#     165 print(f"e6 shape: {e6.shape}", flush=True)
# --> 167 Jr   = eval_component_grid(JRmap,   e6, R3, PHI3, Z3, nx, ny, nz, q)
#     168 Jphi = eval_component_grid(JPHImap, e6, R3, PHI3, Z3, nx, ny, nz, q)
#     169 Jz   = eval_component_grid(JZmap,   e6, R3, PHI3, Z3, nx, ny, nz, q)
#
# File /nfshome/sguotong/projects/CaGe/notebooks/../include/j_eff_from_ana.py:118, in eval_component_grid(coeff_map, e6, R3, PHI3, Z3, nx, ny, nz, q)
#     115 nx, ny, nz   = nx[None,None,None,:], ny[None,None,None,:], nz[None,None,None,:]
#     117 for (j,k), func in coeff_map.items():
# --> 118     C = func(Rb, PHIb, Zb, nx, ny, nz, q)
#     119     acc += C * e6[j][None,None,None,:] * Fvals[k]
#     120 return acc
#
# File <lambdifygenerated-1>:2, in _lambdifygenerated(r, phi, z, nx, ny, nz, Q)
#       1 def _lambdifygenerated(r, phi, z, nx, ny, nz, Q):
# ----> 2     return -1.0*1j*Q*r*sin(phi)*cos(phi) + 1.0*1j*n_x*omega*r**2*sin(phi)*cos(phi)**2 - 1.0*1j*n_y*omega*r**2*cos(phi)**3
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/decorators.py:248, in _SympifyWrapper.make_wrapped.<locals>._func(self, other)
#     246 if not isinstance(other, expectedcls):
#     247     return retval
# --> 248 return func(self, other)
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/decorators.py:118, in call_highest_priority.<locals>.priority_decorator.<locals>.binary_op_wrapper(self, other)
#     116         if f is not None:
#     117             return f(self)
# --> 118 return func(self, other)
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/expr.py:254, in Expr.__mul__(self, other)
#     251 @sympify_return([('other', 'Expr')], NotImplemented)
#     252 @call_highest_priority('__rmul__')
#     253 def __mul__(self, other) -> Expr:
# --> 254     return Mul(self, other)
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/operations.py:108, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#     105 if len(args) == 1:
#     106     return args[0]
# --> 108 c_part, nc_part, order_symbols = cls.flatten(args)
#     109 is_commutative = not nc_part
#     110 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/mul.py:703, in Mul.flatten(cls, seq)
#     699     nc_part = [c for c in nc_part if not (fuzzy_not(c.is_zero) and
#     700                                           c.is_extended_real is not None)]
#     702 # 0
# --> 703 elif coeff.is_zero:
#     704     # we know for sure the result will be 0 except the multiplicand
#     705     # is infinity or a matrix
#     706     if any(isinstance(c, MatrixExpr) for c in nc_part):
#     707         return [coeff], nc_part, order_symbols
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/assumptions.py:566, in _ask(fact, obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
# --> 566     assumptions.deduce_all_facts(((fact_i, fact_i_value),))
#     568 # Usually if assumptions[fact] is now not None then that is because of
#     569 # the call to deduce_all_facts above. The handler for fact_i returned
#     570 # True or False and knowing fact_i (which is equal to fact in the first
#    (...)    573 # called in another thread in a multithreaded context might have
#     574 # resulted in assumptions[fact] being set. Either way we return it.
#     575 fact_value = assumptions.get(fact)
#
# File ~/.conda/envs/.cavGZ_venv/lib/python3.12/site-packages/sympy/core/facts.py:633, in FactKB.deduce_all_facts(self, facts)
#     631 for bidx in beta_maytrigger:
#     632     bcond, bimpl = beta_rules[bidx]
# --> 633     if all(self.get(k) is v for k, v in bcond):
#     634         facts.append(bimpl)
#
# KeyboardInterrupt:

# %%
from include.antenna_pattern import antenna_pattern
from include.custom_types import asarr_np.float64
import numpy as np

Nb, Na, Npsi = 60, 1, 1
beta = np.linspace(0.0, np.pi, Nb, endpoint=True)
alpha = asarr_np.float64(0.0)  # single value for alpha for linear polarization
psi = asarr_np.float64(0)  # single value for psi for linear polarization

pol = "+"

eta = antenna_pattern(r, phi, z, Er, Ephi, Ez, pol=pol, 
                      wg=w_mnp, a=a, L=L, beta=beta, alpha=alpha, psi=psi,
                      savefile="eta_TE211_x.npy")

import numpy as np
import matplotlib.pyplot as plt

PATH = "eta_TE211_x.npy"

eta = np.load(PATH)                        # shape (Nb, Na, Npsi)
curve = eta[:, 0, 0].astype(float)         # take α=0, ψ=0 slice
Nb = curve.size
beta = np.linspace(0.0, np.pi, Nb, endpoint=True)

# Mirror to cover 0..2π without duplicating endpoints
theta_full = np.r_[beta, beta + np.pi]
r_full     = np.r_[curve, curve]

fig = plt.figure(figsize=(6,6), dpi=150)
ax = plt.subplot(111, projection="polar")
ax.plot(theta_full, r_full, linewidth=0.5)   # no color specified
ax.set_theta_zero_location("E")              # 0° at the right
ax.set_theta_direction(1)                   # clockwise (matches your example)
ax.set_rlabel_position(90)                   # radial labels at 90°
ax.grid(True, linewidth=0.8, alpha=0.7)
ax.set_title(PATH.replace(".npy",""), va="bottom")
plt.tight_layout()
plt.show()
# Out:
# Norm is 0.002945558357496856
# E shape after broadcasting: (200, 256, 96, 1, 1, 1)
# Calculating j_eff...
# j shape after broadcasting: (200, 256, 96, 60, 1, 1)
# Finished j_eff calculation, starting integral...
# Finished integral, starting eta calculation...
# Finished eta calculation.
# Saved eta to eta_TE211_x.npy

# %%
family = "TE"
m, n, p = 2, 1, 2
sign = "-"

Er, Ephi, Ez = cavHelper.mode_fn_vectorized(R, PHI, Z, family, m, n, p, sign)
w_mnp = cavHelper.omega_mnp(family, m, n, p)
f_mnp = w_mnp/(2*np.pi)*0.3  # in GHz
print(f"{family}{m}{n}{p}, f={f_mnp:.3g} GHz")

from include.antenna_pattern import antenna_pattern
from include.custom_types import asarr_np.float64

Nb, Na, Npsi = 60, 1, 1
beta = np.linspace(0.0, np.pi, Nb, endpoint=True)
alpha = asarr_np.float64(0.0)  # single value for alpha for linear polarization
psi = asarr_np.float64(0.0)  # single value for psi for linear polarization

pol = "x"

eta = antenna_pattern(r, phi, z, Er, Ephi, Ez, pol=pol, 
                      wg=w_mnp, a=a, L=L, beta=beta, alpha=alpha, psi=psi,
                      savefile="eta_TE212_x.npy")
# Out:
# TE212, f=1.58 GHz
# Norm is 0.003119800375793583
# E shape after broadcasting: (200, 256, 96, 1, 1, 1)
# Calculating j_eff...
# j shape after broadcasting: (200, 256, 96, 60, 1, 1)
# Finished j_eff calculation, starting integral...
# Finished integral, starting eta calculation...
# Finished eta calculation.
# Saved eta to eta_TE212_x.npy

# %%
import numpy as np
import matplotlib.pyplot as plt

PATH = "eta_TE212_x.npy"

eta = np.load(PATH)                        # shape (Nb, Na, Npsi)
curve = eta[:, 0, 0].astype(float)         # take α=0, ψ=0 slice
Nb = curve.size
beta = np.linspace(0.0, np.pi, Nb, endpoint=True)

# Mirror to cover 0..2π without duplicating endpoints
theta_full = np.r_[beta, beta + np.pi]
r_full     = np.r_[curve, curve]

fig = plt.figure(figsize=(6,6), dpi=150)
ax = plt.subplot(111, projection="polar")
ax.plot(theta_full, r_full, linewidth=0.5)   # no color specified
ax.set_theta_zero_location("E")              # 0° at the right
ax.set_theta_direction(1)                   # clockwise (matches your example)
ax.set_rlabel_position(90)                   # radial labels at 90°
ax.grid(True, linewidth=0.8, alpha=0.7)
ax.set_title(PATH.replace(".npy",""), va="bottom")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from include.cavity_modes import CavityModeHelper
from include.antenna_pattern import antenna_pattern
from include.custom_types import asarr_np.float64
from include.j_eff_tmp import j_eff_hat_6d

a = 0.1  # radius in meters
L = 0.5  # length in meters
cavHelper = CavityModeHelper(a, L)

Nr, Nphi, Nz = 200, 256, 96
r = np.linspace(0.0, a, Nr, endpoint=True)
phi = np.linspace(0.0, 2*np.pi, Nphi, endpoint=False)
z = np.linspace(-L/2, +L/2, Nz, endpoint=True)

R, PHI, Z = np.meshgrid(r, phi, z, indexing="ij")   # shape: [Nr, Nphi, Nz]

family = "TE"
m, n, p = 2, 1, 1
sign = "-"

Er, Ephi, Ez = cavHelper.mode_fn_vectorized(R, PHI, Z, family, m, n, p, sign)
w_mnp = cavHelper.omega_mnp(family, m, n, p)
f_mnp = w_mnp/(2*np.pi)*0.3  # in GHz
print(f"{family}{m}{n}{p}, f={f_mnp:.3g} GHz")
# Out:
# TE211, f=1.49 GHz

# %%
Nb, Na, Npsi = 60, 1, 1
beta = np.linspace(0.0, np.pi, Nb, endpoint=True)
alpha = asarr_np.float64(0.0)  # single value for alpha for linear polarization
psi = asarr_np.float64(0)  # single value for psi for linear polarization

pol = "+"
PATH = "tmp_eta_TE211_+.npy"

eta = antenna_pattern(r, phi, z, Er, Ephi, Ez, pol=pol, 
                      wg=w_mnp, a=a, L=L, beta=beta, alpha=alpha, psi=psi,
                      savefile=PATH)

eta = np.load(PATH)                        # shape (Nb, Na, Npsi)
curve = eta[:, 0, 0].astype(float)         # take α=0, ψ=0 slice
Nb = curve.size
beta = np.linspace(0.0, np.pi, Nb, endpoint=True)

# Mirror to cover 0..2π without duplicating endpoints
theta_full = np.r_[beta, beta + np.pi]
r_full     = np.r_[curve, curve]

fig = plt.figure(figsize=(6,6), dpi=150)
ax = plt.subplot(111, projection="polar")
ax.plot(theta_full, r_full, linewidth=0.5)   # no color specified
ax.set_theta_zero_location("E")              # 0° at the right
ax.set_theta_direction(1)                   # clockwise (matches your example)
ax.set_rlabel_position(90)                   # radial labels at 90°
ax.grid(True, linewidth=0.8, alpha=0.7)
ax.set_title(PATH.replace(".npy",""), va="bottom")
plt.tight_layout()
plt.show()
# Out:
# Norm is 0.002945558357496856
# E shape after broadcasting: (200, 256, 96, 1, 1, 1)
# Calculating j_eff...
# j shape after broadcasting: (200, 256, 96, 60, 1, 1)
# Finished j_eff calculation, starting integral...
# Finished integral, starting eta calculation...
# Finished eta calculation.
# Saved eta to tmp_eta_TE211_+.npy
